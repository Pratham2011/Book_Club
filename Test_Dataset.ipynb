# %% [markdown]
# <a href="https://colab.research.google.com/github/Pratham2011/Book_Club/blob/master/Test_Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import pandas as pd

# Upload the dataset
#uploaded = files.upload()

# Assuming your dataset is a CSV file, load it into a DataFrame
#filename = list(uploaded.keys())[0]
df = pd.read_csv('/content/Historical Data for Bitcoin 2014-2021-2.csv')
df.head()
# Display the first few rows of the dataset to ensure it's loaded correctly
# Out:
#   Date;Open;High;Low;Close;Volume;Market Cap Unnamed: 1  Unnamed: 2  \
# 0                                     Dec-20   2021;$46  707.06;$47
# 1                                     Dec-19   2021;$46  853.87;$48
# 2                                     Dec-18   2021;$46  219.26;$47
# 3                                     Dec-17   2021;$47  653.73;$48
# 4                                     Dec-16   2021;$48  900.46;$49
#
#    Unnamed: 3  Unnamed: 4  Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0  401.72;$45  579.81;$46  880.28;$30        961        902   129;$886
# 1  089.66;$46  502.95;$46  707.01;$25        154         53   861;$883
# 2  313.83;$45  598.44;$46  848.78;$26         98        292   690;$885
# 3  004.89;$45  618.22;$46  202.14;$32        902        725   329;$873
# 4  425.57;$47  529.88;$47  665.43;$27        268        150   947;$901
#
#    Unnamed: 9  Unnamed: 10  Unnamed: 11  Unnamed: 12
# 0       331.0        446.0        165.0          NaN
# ...
